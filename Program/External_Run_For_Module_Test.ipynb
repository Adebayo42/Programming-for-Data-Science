# %%
# %run underperformingStudent.py
# Out:
# <style type="text/css">
# #T_e3cb3_row0_col5, #T_e3cb3_row1_col5, #T_e3cb3_row2_col1, #T_e3cb3_row3_col5, #T_e3cb3_row4_col1, #T_e3cb3_row5_col1, #T_e3cb3_row6_col1, #T_e3cb3_row7_col1, #T_e3cb3_row8_col1, #T_e3cb3_row9_col5, #T_e3cb3_row10_col1 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_e3cb3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3cb3_level0_col0" class="col_heading level0 col0" >summative_test</th>
#       <th id="T_e3cb3_level0_col1" class="col_heading level0 col1" >mock_test</th>
#       <th id="T_e3cb3_level0_col2" class="col_heading level0 col2" >test_1</th>
#       <th id="T_e3cb3_level0_col3" class="col_heading level0 col3" >test_2</th>
#       <th id="T_e3cb3_level0_col4" class="col_heading level0 col4" >test_3</th>
#       <th id="T_e3cb3_level0_col5" class="col_heading level0 col5" >test_4</th>
#       <th id="T_e3cb3_level0_col6" class="col_heading level0 col6" >lowest_grade</th>
#     </tr>
# ...

# %%
# %run hardworkingStudents.py
# Out:
#              summative_test programming_knowledge_level
# research_id
# 78                    100.0                    Beginner
# 82                    100.0                    Beginner
# 130                   100.0                    Beginner
# 42                    100.0                    Beginner
# 155                    95.0                    Beginner
# 23                     94.0                    Beginner
# 44                     94.0                    Beginner
# 135                    89.0                    Beginner
# 109                    89.0                    Beginner
# 108                    89.0                    Beginner
# 19                     89.0                    Beginner
# 88                     89.0                    Beginner
# 124                    87.8                    Beginner
# 148                    85.0                    Beginner
# 29                     81.8                    Beginner
# 74                     81.0                    Beginner
# ...

# %%
# %run testResults.py

# %%
# %run studentPerformance.py
# Out:
#        absolute  relative
# grade      56.0     -13.3
# q1        100.0       9.8
# q2        100.0       5.2
# q3        100.0      19.6
# q4        100.0       1.4
# q5          0.0     -62.7
# q6        100.0       9.2
# q7        100.0       3.9
# q8          0.0     -71.7
# q9        100.0      39.6
# q10         0.0     -44.4
# q11         0.0     -54.2
# q12         0.0     -27.5
# q13         0.0     -16.3

# %%
# %run CWPreprocessing.py
# Out:
# Data Preparation: Step 1
# -----------------------------------
# Formative_Mock_Test.csv loaded successfully
# Formative_Test_1.csv loaded successfully
# Formative_Test_2.csv loaded successfully
# Formative_Test_3.csv loaded successfully
# Formative_Test_4.csv loaded successfully
# StudentRate.csv loaded successfully
# SumTest.csv loaded successfully
#
# Step 1 completed!!!
#
# Data Preparation: Step 2
# -----------------------------------
# Null values replaced successfully!
#
# Step 2 completed!!!
#
# Data Preparation: Step 3
# -----------------------------------
# Students hightest test score retained successfully!
#
# Step 3 completed!!!
#
# Data Preparation: Step 4
# -----------------------------------
# Redundant columns excluded successfully!
#
# Step 4 completed!!!
#
# Data Preparation: Step 5
# -----------------------------------
# Grades standardisation completed successfully!
#
# Step 5 completed!!!
#
# Data Preparation: Step 6
# -----------------------------------
# ...

# %%
# %run DAFunction.py
# Out:
#      research_id                 started_on                  completed  grade  \
# 0              1  10 October 2018  10:05 AM  10 October 2018  10:27 AM   95.0
# 1              2   10 October 2018  9:26 AM   10 October 2018  9:35 AM  100.0
# 2              3  10 October 2018  10:07 AM  10 October 2018  10:29 AM  100.0
# 3              4   10 October 2018  4:46 PM   10 October 2018  4:55 PM   96.7
# 4              5  10 October 2018  11:06 AM  10 October 2018  12:09 PM   90.0
# ..           ...                        ...                        ...    ...
# 146          152  10 October 2018  10:15 AM  10 October 2018  10:35 AM   96.7
# 147          153  10 October 2018  10:19 AM  10 October 2018  10:40 AM   80.0
# 148          154  10 October 2018  12:18 PM  10 October 2018  12:35 PM   98.3
# 149          155  10 October 2018  10:00 AM  10 October 2018  10:15 AM   88.3
# 150          156  10 October 2018  10:14 AM  10 October 2018  10:38 AM   68.3
#
# ...
